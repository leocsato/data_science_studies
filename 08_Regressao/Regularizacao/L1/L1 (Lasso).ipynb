# %% [markdown]
# # Exemplo de Regressão Linear

# %% [markdown]
# Este exemplo usa apenas o primeiro recurso do conjunto de dados de diabetes,
# para ilustrar um gráfico bidimensional dessa técnica de regressão.
# regressão. A linha reta pode ser vista no gráfico, mostrando como a
# regressão linear tenta desenhar uma linha reta que melhor minimize
# minimize a soma residual de quadrados entre as respostas observadas
# observadas no conjunto de dados e as respostas previstas pela aproximação linear.
#
# Os coeficientes, a soma residual de quadrados e a pontuação de variância são
# também são calculados.

# %% [raw]
# A Regularização L1, também conhecida como LASSO (Least Absolute Shrinkage and Selection Operator), é uma técnica usada em modelos de regressão para evitar o sobreajuste, onde o modelo se ajusta demais aos dados de treinamento e tem dificuldade em generalizar para novos dados.
#
# A Regularização L1 adiciona um termo à função de custo do modelo, que penaliza os coeficientes de regressão com base na soma dos valores absolutos. Isso leva alguns coeficientes a se tornarem exatamente zero, permitindo a seleção automática de características importantes e resultando em modelos mais simples e interpretáveis.

# %% [markdown]
# ----

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes = datasets.load_diabetes()

# %%
diabetes_X = diabetes.data[:, np.newaxis, 2] # Usa somente 1 feature

# %%
# Divide em treino e teste
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# %%
# Criar Modelo
regr = linear_model.ElasticNet(l1_ratio=1)

# %%
# Treina Modelo
regr.fit(diabetes_X_train,
         diabetes_y_train)
# Out:
# ElasticNet(l1_ratio=1)

# %%
# Predições de Teste
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# Coeficientes de Regressão
print('Coeficientes: \n', regr.coef_)
# Resíduo
print("MSE: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Métrica de Avaliação
print('R2: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coeficientes:
#  [496.66920971]
# MSE: 3482.77
# R2: 0.28

# %%
# Gráficos
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)
plt.xticks(())
plt.yticks(())
plt.show()
