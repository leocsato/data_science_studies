# %%
import numpy as np
import scipy
import seaborn as sns

# %%
# Variáveis aleatórias de uma distribuição beta
variaveis = scipy.stats.beta.rvs(5, 5, loc=0, scale=1, size=500)

# %%
# (a, b, loc, scale)
params = scipy.stats.beta.fit(variaveis)

# %%
# Calcula PDF
x = np.linspace(0, 1, 500)
pdf = scipy.stats.beta.pdf(x, *params)

# %%
sns.lineplot(x= x, y=pdf)
# Out:
# <Axes: >

# %%
sns.histplot(variaveis)
# Out:
# <Axes: ylabel='Count'>
